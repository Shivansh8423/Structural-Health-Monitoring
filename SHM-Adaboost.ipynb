# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from io import StringIO
from sklearn.preprocessing import MinMaxScaler
import sklearn
# test regression dataset
from sklearn.datasets import make_regression#1
from sklearn.ensemble import AdaBoostRegressor#2
from sklearn.metrics import r2_score,mean_squared_error

# %%
dataset = pd.read_csv('/content/drive/MyDrive/SHM final dataset/finaldataset.csv', dtype='unicode')
dataset.head(n=3)
dataset.shape
# Out:
# (150948, 6)

# %%
#normalisation
scaler=MinMaxScaler()
scaler.fit(dataset.iloc[:,5:6])
dataset["Ground truth"]=scaler.transform(dataset.iloc[:,5:6])
dataset
# Out:
#          Cycle Load frequency          PSD        TOF  Ground truth
# 0            0    0       150  0.004458466  1654.5848      0.000000
# 1            0    0       150     4.69E-07  1367.5206      0.000000
# 2            0    0       150     1.90E-05  1420.0662      0.000000
# 3            0    0       150  0.004027539  782.64905      0.000000
# 4            0    0       150  0.002709271  472.53552      0.000000
# ...        ...  ...       ...          ...        ...           ...
# 150943  800000    0       250     7.04E-08  52.080139      0.930166
# 150944  800000    0       300     5.34E-08  1018.7769      0.930166
# 150945  800000    0       350     5.26E-08  1623.8937      0.930166
# 150946  800000    0       400     2.95E-08  1286.5857      0.930166
# 150947  800000    0       450     5.94E-08  664.61493      0.930166
#
# [150948 rows x 6 columns]

# %%
#To fix x value
X=dataset.iloc[:,0:5].values
#print(X)

# %%
#To fix Y value
y=dataset.iloc[:,5].values
# print(y)

# %%
#To fix train and test data
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.25,random_state=20000)

# %%
#adaboost algo
model=AdaBoostRegressor(n_estimators = 200, learning_rate =
1.0, random_state = 80,loss='linear')
model.fit(X_train,Y_train)
#build boosted regressor from training set
# Out:
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                   n_estimators=200, random_state=80)

# %%
#To prediction
Y_pred=model.predict(X_test)#predict regression value for X_test
model.score(X,y)#return the coefficient of determination R^2 of prediction
#r2=r2_score(Y_test,Y_pred)
#r2
#plt.scatter(dataset["Cycle"],dataset["Ground truth"])
#plt.title("adaboost")
# Out:
# 0.947910792748475

# %%
r2_score(Y_test,Y_pred)#r2_score(y_true, y_pred)
# Out:
# 0.9467468263625126

# %%
Y_pred_x=model.predict(X_train)
r2_score(Y_train,Y_pred_x)
# Out:
# 0.9480422311648077

# %%
#Formula for calculating RMSE
mse=mean_squared_error(Y_test, Y_pred)
print(mse)
rmse=np.sqrt(mse)
rmse
#mean_squared_error(Y_test,Y_pred)
# Out:
# 0.00251179926841214
# 0.05011785378896567
